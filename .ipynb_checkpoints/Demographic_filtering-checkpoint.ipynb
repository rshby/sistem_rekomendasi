# %%
import json
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="talk")

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_distances

# %%
df = pd.read_csv("dataset/IMDb movies.csv", low_memory=False)
df.loc[df["year"] == "TV Movie 2019", "year"] = "2019"
df["year"] = df["year"].astype("int")

# %%
df.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
#
#    year date_published                    genre  duration           country  \
# 0  1894     1894-10-09                  Romance        45               USA
# 1  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#   language         director  ...  \
# 0     None  Alexander Black  ...
# 1     None     Charles Tait  ...
# 2      NaN        Urban Gad  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
#
#                                          description avg_vote votes  budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154     NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589  $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188     NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
#
# [3 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  int32
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
#  14  avg_vote               85855 non-null  float64
#  15  votes                  85855 non-null  int64
#  16  budget                 23710 non-null  object
#  17  usa_gross_income       15326 non-null  object
#  18  worlwide_gross_income  31016 non-null  object
#  19  metascore              13305 non-null  float64
#  20  reviews_from_users     78258 non-null  float64
#  21  reviews_from_critics   74058 non-null  float64
# dtypes: float64(4), int32(1), int64(2), object(15)
# memory usage: 14.1+ MB

# %%
df.dropna(subset=["year"], inplace=True)

# %%
df["year"].unique()
# Out:
# array([1894, 1906, 1911, 1912, 1919, 1913, 1914, 1915, 1916, 1917, 1918,
#        1920, 1921, 1924, 1922, 1923, 1925, 1926, 1935, 1927, 1928, 1983,
#        1929, 1930, 1932, 1931, 1937, 1938, 1933, 1934, 1936, 1940, 1939,
#        1942, 1943, 1941, 1948, 1944, 2001, 1946, 1945, 1947, 1973, 1949,
#        1950, 1952, 1951, 1962, 1953, 1954, 1955, 1961, 1956, 1958, 1957,
#        1959, 1960, 1963, 1965, 1971, 1964, 1966, 1968, 1967, 1969, 1976,
#        1970, 1979, 1972, 1981, 1978, 2000, 1989, 1975, 1974, 1986, 1990,
#        2018, 1977, 1982, 1980, 1993, 1984, 1985, 1988, 1987, 2005, 1991,
#        2002, 1994, 1992, 1995, 2017, 1997, 1996, 2006, 1999, 1998, 2007,
#        2008, 2003, 2004, 2010, 2009, 2011, 2013, 2012, 2016, 2015, 2014,
#        2019, 2020])

# %%
rekomen = df[(df["year"] > 2019) & (df["avg_vote"] > 9)].sort_values(by="avg_vote", ascending=False).head(10).to_json(orient="records")

# %%
data = json.loads(rekomen)

# %%
data[0]
# Out:
# {'imdb_title_id': 'tt11207902',
#  'title': 'Lejos de Casa pelicula Venezolana',
#  'original_title': 'Lejos de Casa pelicula Venezolana',
#  'year': 2020,
#  'date_published': '2020-03-19',
#  'genre': 'Drama, History',
#  'duration': 87,
#  'country': 'Venezuela',
#  'language': 'Spanish',
#  'director': 'Abner Official',
#  'writer': 'Dariana Jozh, Abner Official',
#  'production_company': None,
#  'actors': 'Angibell, Gabriel Buitrago, Darwing, Dariana Jozh, Marko, Abner Official, Yroski',
#  'description': 'Samuel, a young Venezuelan, emigrates from his country in search of a better life and to help his family, without knowing the difficult situations that he will face as an immigrant.',
#  'avg_vote': 9.8,
#  'votes': 133,
#  'budget': '$ 5000',
#  'usa_gross_income': None,
#  'worlwide_gross_income': None,
#  'metascore': None,
#  'reviews_from_users': None,
#  'reviews_from_critics': None}

# %% [markdown]
# # Content Based -> Description

# %%
df.dropna(subset=["description"], inplace=True)

# %%
df.head(30)
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 1      tt0000574                        The Story of the Kelly Gang
# 2      tt0001892                                     Den sorte drøm
# 3      tt0002101                                          Cleopatra
# 4      tt0002130                                          L'Inferno
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 6      tt0002423                                     Madame DuBarry
# 7      tt0002445                                         Quo Vadis?
# 8      tt0002452                              Independenta Romaniei
# 9      tt0002461                                        Richard III
# 10     tt0002646                                           Atlantis
# 11     tt0002844              Fantômas - À l'ombre de la guillotine
# 12     tt0003014                           Il calvario di una madre
# 13     tt0003037                               Juve contre Fantômas
# 14     tt0003102                         Ma l'amor mio non muore...
# 15     tt0003131                             Maudite soit la guerre
# 16     tt0003165                                    Le mort qui tue
# 17     tt0003167                                     Amore di madre
# 18     tt0003419                               Lo studente di Praga
# 19     tt0003471                                   Traffic in Souls
# 20     tt0003489                        Gli ultimi giorni di Pompei
# 21     tt0003637                                      Assunta Spina
# 22     tt0003643  The Avenging Conscience: or 'Thou Shalt Not Kill'
# 23     tt0003657                                        The Bargain
# 24     tt0003740                                            Cabiria
# 25     tt0003772                                         Cinderella
# 26     tt0003883                                  L'enfant de Paris
# 27     tt0003930                           Fantômas contre Fantômas
# 28     tt0003973                              A Florida Enchantment
# 29     tt0004026                                          Der Golem
#
#                                        original_title  year date_published  \
# 0                                          Miss Jerry  1894     1894-10-09
# 1                         The Story of the Kelly Gang  1906     1906-12-26
# 2                                      Den sorte drøm  1911     1911-08-19
# 3                                           Cleopatra  1912     1912-11-13
# 4                                           L'Inferno  1911     1911-03-06
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# 6                                      Madame DuBarry  1919     1919-11-26
# 7                                          Quo Vadis?  1913     1913-03-01
# 8                               Independenta Romaniei  1912     1912-09-01
# 9                                         Richard III  1912     1912-10-15
# 10                                           Atlantis  1913     1913-12-26
# 11              Fantômas - À l'ombre de la guillotine  1913     1913-05-12
# 12                                      Ingeborg Holm  1913     1915-10-18
# 13                               Juve contre Fantômas  1913     1913-09-08
# 14                         Ma l'amor mio non muore...  1914     1914-01-01
# 15                             Maudite soit la guerre  1914     1914-05-01
# 16                                    Le mort qui tue  1913     1913-11-06
# 17                                   Home, Sweet Home  1914     1914-05-17
# 18                               Der Student von Prag  1913     1913-08-22
# 19                                   Traffic in Souls  1913     1913-11-24
# 20                        Gli ultimi giorni di Pompei  1913     1913-08-24
# 21                                      Assunta Spina  1915     1916-05-01
# 22  The Avenging Conscience: or 'Thou Shalt Not Kill'  1914     1914-08-24
# 23                                        The Bargain  1914     1914-12-03
# 24                                            Cabiria  1914     1914-04-18
# 25                                         Cinderella  1914     1914-12-28
# 26                                  L'enfant de Paris  1913     1913-09-17
# 27                           Fantômas contre Fantômas  1914     1914-01-10
# 28                              A Florida Enchantment  1914     1916-09-04
# 29                                          Der Golem  1915     1915-04-08
#
#                         genre  duration           country         language  \
# 0                     Romance        45               USA             None
# 1     Biography, Crime, Drama        70         Australia             None
# 2                       Drama        53  Germany, Denmark              NaN
# 3              Drama, History       100               USA          English
# 4   Adventure, Drama, Fantasy        68             Italy          Italian
# 5            Biography, Drama        60               USA          English
# 6   Biography, Drama, Romance        85           Germany           German
# 7              Drama, History       120             Italy          Italian
# 8                History, War       120           Romania              NaN
# 9                       Drama        55       France, USA          English
# 10                      Drama       121           Denmark           Danish
# 11               Crime, Drama        54            France           French
# 12                      Drama        96            Sweden              NaN
# 13               Crime, Drama        61            France           French
# 14                      Drama        90             Italy          Italian
# 15                 Drama, War        50           Belgium           French
# 16      Crime, Drama, Mystery        90            France           French
# 17                      Drama        55               USA          English
# 18     Drama, Fantasy, Horror        85           Germany  German, English
# 19               Crime, Drama        88               USA          English
# 20           Adventure, Drama        88             Italy          Italian
# 21                      Drama        72             Italy              NaN
# 22       Crime, Drama, Horror        78               USA          English
# 23                    Western        70               USA          English
# 24  Adventure, Drama, History       148             Italy          Italian
# 25             Fantasy, Drama        52               USA          English
# 26               Crime, Drama       124            France           French
# 27               Crime, Drama        59            France           French
# 28                     Comedy        63               USA          English
# 29                     Horror        60           Germany           German
#
#                                  director  ...  \
# 0                         Alexander Black  ...
# 1                            Charles Tait  ...
# 2                               Urban Gad  ...
# 3                      Charles L. Gaskill  ...
# 4     Francesco Bertolini, Adolfo Padovan  ...
# 5                           Sidney Olcott  ...
# 6                          Ernst Lubitsch  ...
# 7                         Enrico Guazzoni  ...
# 8   Aristide Demetriade, Grigore Brezeanu  ...
# 9            André Calmettes, James Keane  ...
# 10                            August Blom  ...
# 11                        Louis Feuillade  ...
# 12                        Victor Sjöström  ...
# 13                        Louis Feuillade  ...
# 14                         Mario Caserini  ...
# 15                          Alfred Machin  ...
# 16                        Louis Feuillade  ...
# 17                          D.W. Griffith  ...
# 18              Paul Wegener, Stellan Rye  ...
# 19                    George Loane Tucker  ...
# 20      Mario Caserini, Eleuterio Rodolfi  ...
# 21      Francesca Bertini, Gustavo Serena  ...
# 22                          D.W. Griffith  ...
# 23                        Reginald Barker  ...
# 24                      Giovanni Pastrone  ...
# 25                         James Kirkwood  ...
# 26                          Léonce Perret  ...
# 27                        Louis Feuillade  ...
# 28                            Sidney Drew  ...
# 29            Henrik Galeen, Paul Wegener  ...
#
#                                                actors  \
# 0   Blanche Bayliss, William Courtenay, Chauncey D...
# 1   Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2   Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3   Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4   Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 5   R. Henderson Bland, Percy Dyer, Gene Gauntier,...
# 6   Pola Negri, Emil Jannings, Harry Liedtke, Edua...
# 7   Amleto Novelli, Gustavo Serena, Carlo Cattaneo...
# 8   Aristide Demetriade, Constanta Demetriade, Con...
# 9   Robert Gemp, Frederick Warde, Albert Gardner, ...
# 10  Olaf Fønss, Ida Orloff, Ebba Thomsen, Carl Lau...
# 11  René Navarre, Edmund Breon, Georges Melchior, ...
# 12  Hilda Borgström, Aron Lindgren, Erik Lindholm,...
# 13  René Navarre, Edmund Breon, Georges Melchior, ...
# 14  Lyda Borelli, Mario Bonnard, Gian Paolo Rosmin...
# 15  Baert, Suzanne Berni, Fernand Crommelynck, Nad...
# 16  René Navarre, Edmund Breon, Georges Melchior, ...
# 17  Henry B. Walthall, Josephine Crowell, Lillian ...
# 18  Paul Wegener, Grete Berger, Lyda Salmonova, Jo...
# 19  Jane Gail, Ethel Grandin, William H. Turner, M...
# 20  Fernanda Negri Pouget, Eugenia Tettoni Fior, U...
# 21  Francesca Bertini, Gustavo Serena, Carlo Benet...
# 22  Henry B. Walthall, Spottiswoode Aitken, Blanch...
# 23  William S. Hart, J. Frank Burke, Clara William...
# 24  Carolina Catena, Lidia Quaranta, Gina Marangon...
# 25  Mary Pickford, Owen Moore, Isabel Vernon, Geor...
# 26  Léonce Perret, Louis Leubas, Maurice Lagrenée,...
# 27  René Navarre, Georges Melchior, Laurent Morléa...
# 28  Sidney Drew, Edith Storey, Charles Kent, Mrs. ...
# 29  Paul Wegener, Henrik Galeen, Lyda Salmonova, R...
#
#                                           description avg_vote votes  \
# 0   The adventures of a female reporter in the 1890s.      5.9   154
# 1   True story of notorious Australian outlaw Ned ...      6.1   589
# 2   Two men of high rank are both wooing the beaut...      5.8   188
# 3   The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4   Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# 5   An account of the life of Jesus Christ, based ...      5.7   484
# 6   The story of Madame DuBarry, the mistress of L...      6.8   753
# 7   An epic Italian film "Quo Vadis" influenced ma...      6.2   273
# 8   The movie depicts the Romanian War of Independ...      6.7   198
# 9   Richard of Gloucester uses manipulation and mu...      5.5   225
# 10  After Dr. Friedrich's wife becomes mentally un...      6.6   331
# 11  Inspector Juve is tasked to investigate and ca...      7.0  1944
# 12  Single mother is separated from her children d...      7.1   948
# 13  In Part Two of Louis Feuillade's 5 1/2-hour ep...      7.0  1349
# 14  Leslie Swayne, an adventurer, in order to obta...      6.2   100
# 15  An army pilot is on a visit at the home of ano...      6.5   124
# 16  After a body disappears from inside the prison...      7.0  1050
# 17  John Howard Payne at his most miserable point ...      5.8   187
# 18  Balduin, a student of Prague, leaves his royst...      6.5  1768
# 19  A woman, with the aid of her police officer sw...      6.0   552
# 20    Two love triangles intersect in ancient Pompei.      6.2   474
# 21  Assunta Spina is a tragedy set in Naples at th...      6.4   378
# 22  Prevented from dating his sweetheart by his un...      6.4  1105
# 23  After the bandit Jim Stokes robs the stage he ...      6.5   144
# 24  Cabiria is a Roman child when her home is dest...      7.1  3073
# 25  Though mistreated by her cruel stepmother and ...      6.0   929
# 26  The young daughter of an army captain missing ...      7.5   303
# 27  The mystery of the drama is the appearance of ...      6.9  1161
# 28  A young woman discovers a seed that can make w...      5.8   202
# 29  In this version of the golem legend, the golem...      6.8  1040
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN               NaN                   NaN       NaN
# 1       $ 2250               NaN                   NaN       NaN
# 2          NaN               NaN                   NaN       NaN
# 3      $ 45000               NaN                   NaN       NaN
# 4          NaN               NaN                   NaN       NaN
# 5          NaN               NaN                   NaN       NaN
# 6          NaN               NaN                   NaN       NaN
# 7    ITL 45000               NaN                   NaN       NaN
# 8   ROL 400000               NaN                   NaN       NaN
# 9      $ 30000               NaN                   NaN       NaN
# 10         NaN               NaN                   NaN       NaN
# 11         NaN               NaN                   NaN       NaN
# 12         NaN               NaN                   NaN       NaN
# 13         NaN               NaN                   NaN       NaN
# 14         NaN               NaN                   NaN       NaN
# 15         NaN               NaN                   NaN       NaN
# 16         NaN               NaN                   NaN       NaN
# 17         NaN               NaN                   NaN       NaN
# 18         NaN               NaN                   NaN       NaN
# 19      $ 5700               NaN                   NaN       NaN
# 20         NaN               NaN                   NaN       NaN
# 21         NaN               NaN                   NaN       NaN
# 22         NaN               NaN                   NaN       NaN
# 23         NaN               NaN                   NaN       NaN
# 24    $ 210000               NaN                   NaN       NaN
# 25         NaN               NaN                   NaN       NaN
# 26         NaN               NaN                   NaN       NaN
# 27         NaN               NaN                   NaN       NaN
# 28         NaN               NaN                   NaN       NaN
# 29         NaN               NaN                   NaN       NaN
#
#    reviews_from_users  reviews_from_critics
# 0                 1.0                   2.0
# 1                 7.0                   7.0
# 2                 5.0                   2.0
# 3                25.0                   3.0
# 4                31.0                  14.0
# 5                13.0                   5.0
# 6                12.0                   9.0
# 7                 7.0                   5.0
# 8                 4.0                   1.0
# 9                 8.0                   1.0
# 10                9.0                   9.0
# 11                9.0                  28.0
# 12               16.0                   7.0
# 13                8.0                  23.0
# 14                NaN                   4.0
# 15                2.0                   2.0
# 16                6.0                  18.0
# 17                6.0                   NaN
# 18               20.0                  26.0
# 19               14.0                  11.0
# 20               13.0                   7.0
# 21                7.0                   2.0
# 22               14.0                  11.0
# 23                8.0                   3.0
# 24               31.0                  26.0
# 25               10.0                   3.0
# 26                7.0                   4.0
# 27                5.0                  18.0
# 28                6.0                   3.0
# 29                5.0                   NaN
#
# [30 rows x 22 columns]

# %%
bow = CountVectorizer(stop_words="english", tokenizer=word_tokenize)
bank = bow.fit_transform(df["description"])

# %% [markdown]
# ## Step 1: Encode what use watch

# %%
user_imdb_title_id = "tt0003772"

# %%
konten = df.loc[df["imdb_title_id"] == user_imdb_title_id, "description"]

# %%
code = bow.transform(konten)

# %%
konten
# Out:
# 25    Though mistreated by her cruel stepmother and ...
# Name: description, dtype: object

# %%
df.reindex(columns=["description"], index=df[df["imdb_title_id"] == "tt0042229"].index)["description"]
# Out:
# 3    The fabled queen of Egypt's affair with Roman ...
# Name: description, dtype: object

# %%
konten = df.reindex(columns=["description"], index=df[df["imdb_title_id"] == "tt0342556"].index)["description"]
code = bow.transform(konten)
distance = cosine_distances(code, bank)
rec_idx = distance.argsort()[0, 1:11]
hasil_rekomendasi = df.loc[rec_idx].to_json(orient="records")
hasil_rekomendasi
# Out:
# '[{"imdb_title_id":"tt2340888","title":"Survivors","original_title":"Survivors","year":2015,"date_published":"2015-10-18","genre":"Drama, Horror, Thriller","duration":92,"country":"UK","language":"English","director":"Adam Spinks","writer":"Adam Spinks, Laurence Timms","production_company":"Initiative Motion Pictures","actors":"David Anderson, Adrian Annis, Simon Burbage, Lucy Chappell, Ali Currey, Steve Davis, Nathaniel Francis, Joanne Gale, David Anthony Green, Alan Harman, Lauren Hutchings, Luke Kaile, Lydia Kay, Rich Keeble, Antony D. Lane","description":"The outbreak of a deadly virus sends the UK into a state of emergency, into a war it appears destined to lose. In a world without laws, without order and without anybody watching... how far would you go to survive?","avg_vote":4.5,"votes":109,"budget":"GBP 10000","usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":3.0,"reviews_from_critics":22.0},{"imdb_title_id":"tt0098391","title":"Stradivari","original_title":"Stradivari","year":1988,"date_published":"1988-09-28","genre":"Biography, Drama","duration":110,"country":"Italy, France","language":"Italian","director":"Giacomo Battiato","writer":"Giacomo Battiato, Suso Cecchi D\'Amico","production_company":"Cinecitt\\u00e0","actors":"Anthony Quinn, Stefania Sandrelli, Val\\u00e9rie Kaprisky, Francesco Quinn, Danny Quinn, Lorenzo Quinn, Fanny Bastien, Jean-Paul Muel, Stefano Mosini, Leopoldo Trieste, Michael Valeri, Patrizia De Clara, Benedetto Fanna, Stefano Gragnani, Graziella Diano","description":"As a boy the orphan Antonio Stradivari heard for the first time in his life the sound of a violin and he was fascinated by its voice. He tried to construct a violin and attracted the ...","avg_vote":6.4,"votes":345,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":1.0,"reviews_from_critics":null},{"imdb_title_id":"tt0117187","title":"Nitrato d\'argento","original_title":"Nitrato d\'argento","year":1996,"date_published":"1997-01-29","genre":"Comedy, Drama, History","duration":87,"country":"Italy, France, Hungary","language":"Italian, Hungarian, French, English, German, Spanish","director":"Marco Ferreri","writer":"Marco Ferreri, Gianni Romoli","production_company":"Audifilm","actors":"L\\u00e1szl\\u00f3 Balogh, \\u00c9ric Berger, Marc Berman, Doriana Bianchi, V\\u00e9ronique Blainvy, J\\u00e1nos Breckl, Lavinia Centrone, Dario Costa, P\\u00e9ter Cseke, Gabriella Csizmadia, Lucianna De Falco, Iaia Forte, Gl\\u00f3ria Geszty, Dylan Gray, Body G\\u00e0sp\\u00e0r","description":"The film celebrates the 100th anniversary of the birth of cinema. It presents the technical and artistic evolution of the motion pictures. We move from mute to sound, from black-and-white ...","avg_vote":6.8,"votes":109,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":null,"reviews_from_critics":2.0},{"imdb_title_id":"tt0120861","title":"La teoria del volo","original_title":"The Theory of Flight","year":1998,"date_published":"1999-06-18","genre":"Comedy, Drama, Romance","duration":101,"country":"UK","language":"English","director":"Paul Greengrass","writer":"Richard Hawkins","production_company":"Distant Horizon","actors":"Helena Bonham Carter, Kenneth Branagh, Gemma Jones, Holly Aird, Ray Stevenson, Sue Jones-Davies, Gwenyth Petty, Robert Blythe, Aneirin Hughes, Natasha Williams, Sian Naiomi, Ruth Jones, Nia Roberts, Dilys Price, Jill James","description":"Two miserable people find happiness together: a man dreaming of flying, and a woman dreaming of living.","avg_vote":6.5,"votes":2436,"budget":null,"usa_gross_income":"$ 73233","worlwide_gross_income":"$ 73233","metascore":48.0,"reviews_from_users":32.0,"reviews_from_critics":18.0},{"imdb_title_id":"tt0215715","title":"O Dia da Ca\\u00e7a","original_title":"O Dia da Ca\\u00e7a","year":2000,"date_published":"2000-06-05","genre":"Action, Crime, Thriller","duration ...

# %%
df.reindex(index=rec_idx).to_json(orient="records")
# Out:
# '[{"imdb_title_id":"tt0083367","title":"Il cuore del tiranno","original_title":"A zsarnok sz\\u00edve, avagy Boccaccio Magyarorsz\\u00e1gon","year":1981,"date_published":"1981-10-26","genre":"Drama, History","duration":96,"country":"Hungary, Italy","language":"Hungarian","director":"Mikl\\u00f3s Jancs\\u00f3","writer":"Giovanna Gagliardo, Gyula Hern\\u00e1di","production_company":"Mafilm","actors":"Teresa Ann Savoy, L\\u00e1szl\\u00f3 G\\u00e1lffi, J\\u00f3zsef Madaras, Ninetto Davoli, L\\u00e1szl\\u00f3 M\\u00e1rkus, G\\u00e9za D. Heged\\u00fcs, Gy\\u00f6rgy Cserhalmi, Mikl\\u00f3s K\\u00f6ll\\u00f5, G\\u00e1bor D\\u00f3ra, Mih\\u00e1ly Csik\\u00f3s, Katalin D\\u00f5ry, \\u00c9va Preisinger, Ir\\u00e9n Kisp\\u00e1l, Katalin Preisinger-Keller, G\\u00e9za Melczer-Luk\\u00e1cs","description":"A historical drama set in the 1400s, about a young man sent to Italy but is forced back after his father\'s mysterious death.","avg_vote":6.8,"votes":118,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":1.0,"reviews_from_critics":null},{"imdb_title_id":"tt0028776","title":"Death in the Air","original_title":"Death in the Air","year":1936,"date_published":"1936-12-01","genre":"Action, Adventure, Mystery","duration":69,"country":"USA","language":"English","director":"Elmer Clifton","writer":"Bernard McConville, Charles R. Condon","production_company":"Fanchon Royer Pictures","actors":"Lona Andre, John Carroll, Leon Ames, Henry Hall, John S. Peters, Gaston Glass, Pat Somerset, Wheeler Oakman, Reed Howes, John Elliott, Willard Kent","description":"Aircraft are being shot down by a large black plane with a big \\"X\\" painted on the wing. The chief suspects are invited for the weekend to an old dark mansion.","avg_vote":5.3,"votes":120,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":8.0,"reviews_from_critics":1.0},{"imdb_title_id":"tt0079859","title":"Uno sceriffo extraterrestre... poco extra e molto terrestre","original_title":"Uno sceriffo extraterrestre... poco extra e molto terrestre","year":1979,"date_published":"1979-08-10","genre":"Action, Comedy, Family","duration":95,"country":"Italy","language":"Italian, English","director":"Michele Lupo","writer":"Marcello Fondato, Francesco Scardamaglia","production_company":"Leone Film","actors":"Bud Spencer, Raimund Harmstorf, Cary Guffey, Joe Bugner, Carlo Reali, Luigi Bonos, Harold E. Finch, Dino Emanuelli, Giancarlo Bastianoni, Giovanni Cianfriglia, Ottaviano Dell\'Acqua, Roberto Dell\'Acqua, Vincenzo Maggio, Riccardo Pizzuti, Claudio Ruffini","description":"A young humanoid alien who gets stranded on earth hooks up with a grizzled old sheriff in a western town and tries to help him solve a tough case, but the sheriff doesn\'t want any help from a \\"kid.\\"","avg_vote":6.2,"votes":3420,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":11.0,"reviews_from_critics":5.0},{"imdb_title_id":"tt1821426","title":"Weekend in famiglia","original_title":"Family Weekend","year":2013,"date_published":"2013-03-29","genre":"Comedy, Drama","duration":105,"country":"USA","language":"English","director":"Benjamin Epps","writer":"Matt K. Turner","production_company":"Footprint Features","actors":"Kristin Chenoweth, Matthew Modine, Olesya Rulin, Joey King, Shirley Jones, Eddie Hassell, Chloe Bridges, Adam Saunders, Robbie Tucker, Peter Gail, Chase Yi, Lauren LaStrada, Paul Black","description":"When her family misses her jump roping competition, a 16-year-old girl and her siblings hold their parents hostage, hoping to correct their unsatisfying behavior.","avg_vote":6.2,"votes":6583,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":35.0,"reviews_from_users":24.0,"reviews_from_critics":35.0},{"imdb_title_id":"tt0081989","title":"Gli altri giorni del condor","original_title":"Agency","year":1980,"date_published":"1980-09-05 ...

# %% [markdown]
# ## Step 2: Mencari Similarity

# %%
distance = cosine_distances(code, bank)
distance
# Out:
# array([[0.88047714, 0.9194177 , 0.8511125 , ..., 0.83281654, 0.79955407,
#         0.72996914]])

# %%
rec_idx = distance.argsort()[0, 1:11]
rec_idx
# Out:
# array([ 6399, 11919, 17727, 10042, 19686, 78079, 37423,  1974, 56526,
#        55308], dtype=int64)

# %% [markdown]
# ## Step 3: Rekomen

# %%
df.loc[rec_idx].to_json(orient="records")
# Out:
# '[{"imdb_title_id":"tt0042229","title":"Il barone dell\'Arizona","original_title":"The Baron of Arizona","year":1950,"date_published":"1951-01-24","genre":"Biography, Crime, Drama","duration":97,"country":"USA","language":"English","director":"Samuel Fuller","writer":"Samuel Fuller","production_company":"Deputy Corporation","actors":"Vincent Price, Ellen Drew, Vladimir Sokoloff, Beulah Bondi, Reed Hadley, Robert Barrat, Robin Short, Tina Pine, Karen Kester, Margia Dean, Jonathan Hale, Edward Keane, Barbara Wooddell, I. Stanford Jolley, Fred Kohler Jr.","description":"Master swindler James Reavis painstakingly spends years forging documents and land grants that will make his wife and him undisputed owners of the entire state of Arizona.","avg_vote":7.0,"votes":1877,"budget":"$ 135000","usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":35.0,"reviews_from_critics":29.0},{"imdb_title_id":"tt0058312","title":"Maciste, gladiatore di Sparta","original_title":"Maciste, gladiatore di Sparta","year":1964,"date_published":"1964-03-26","genre":"Adventure, Drama","duration":103,"country":"Italy, France","language":"Italian","director":"Mario Caiano","writer":"Mario Amendola, Alfonso Brescia","production_company":"Prometeo Film S.r.l.","actors":"Mark Forest, Maril\\u00f9 Tolo, Elisabetta Fanti, Robert Hundar, Franco Cobianchi, Giuseppe Addobbati, Ferruccio Amendola, Ugo Attanasio, Lea Monaco, Renato Navarrini, Jacques Stany, Bruno Ukmar, Enrico Salvatore","description":"Maciste fights for right and might against the wicked Caesar.","avg_vote":4.7,"votes":171,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":6.0,"reviews_from_critics":6.0},{"imdb_title_id":"tt0075238","title":"La linea d\'ombra","original_title":"Smuga cienia","year":1976,"date_published":"1976-09-06","genre":"Drama","duration":100,"country":"Poland, UK","language":"English, Polish","director":"Andrzej Wajda","writer":"Joseph Conrad, Boleslaw Sulik","production_company":"Thames Television","actors":"Marek Kondrat, Graham Lines, Tom Wilkinson, Bernard Archard, John Bennett, Martin Wyldeck, Richard Bartlett, Piotr Cieslak, Zygmunt H\\u00fcbner, Eugeniusz Priwieziencew, Gordon Richardson, Stanislaw Tym, Jerzy Zelnik, Tadeusz Bartosik, Malgorzata Braunek","description":"From Joseph Conrad\'s great novel comes the story of a young seaman trying to helm a damaged boat to Singapore and dealing with many unfortunate events. While on command of the situation, he...","avg_vote":5.9,"votes":112,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":2.0,"reviews_from_critics":2.0},{"imdb_title_id":"tt0053100","title":"Nat\\u00fcrlich die Autofahrer","original_title":"Nat\\u00fcrlich die Autofahrer","year":1959,"date_published":"1959-08-20","genre":"Comedy","duration":82,"country":"West Germany","language":"German","director":"Erich Engels","writer":"Gustav Kampendonk","production_company":"Deutsche Film Hansa","actors":"Heinz Erhardt, Maria Perschy, Erik Schumann, Ruth Stephan, Trude Herr, Margitta Scherr, Edith Hancke, Arne Madin, Ralf Wolter, Willy Maertens, Bob Iller, Hans Paetsch, J\\u00f6ns Andersson, Klaus Behrendt, Peter Frankenfeld","description":"Eberhard Dobermann is a widower and a policeman who loves to control the roads and let people pay fines. Even with his neighbour and friend Jutta Schmalbach he has no pity. Thus he cannot ...","avg_vote":6.4,"votes":338,"budget":null,"usa_gross_income":null,"worlwide_gross_income":null,"metascore":null,"reviews_from_users":2.0,"reviews_from_critics":2.0},{"imdb_title_id":"tt0081620","title":"Theo gegen den Rest der Welt","original_title":"Theo gegen den Rest der Welt","year":1980,"date_published":"1980-09-25","genre":"Comedy, Crime, Romance","duration":106,"country":"West Germany","language":"German","director":"Peter F. Bringmann","writer":"Matthias Seelig","production_company":"Tura-Film","a ...
